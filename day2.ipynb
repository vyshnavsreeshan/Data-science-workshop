# %%
print(int(input("Enter a number to be added:")) + 5)
print(int(input("Enter a number to be multiplied:")) * 6)
print(int(input("Enter a number subtracted:")) - 4)
print(int(input("Enter a number divided:")) / 2)
# Out:
# Enter a number to be added:5
# 10
# Enter a number to be multiplied:6
# 36
# Enter a number subtracted:7
# 3
# Enter a number divided:8
# 4.0

# %%
x=int(input("Enter a number:"))
print("After addition:",x+5 )
print("After multiplication:",x*6)
print("After subtraction:",x-4)
print("After division:",x/2)
# Out:
# Enter a number:5
# After addition: 10
# After multiplication: 30
# After subtraction: 1
# After division: 2.5

# %%
x=int(input("Enter first number:"))
y=int(input("Enter second number:"))
print("Sum of two number:", x+y)
print("Difference of two numbers:", x-y)
print("Product of two numbers:", x*y)
print("After division:", x/y)
# Out:
# Enter first number:10
# Enter second number:5
# Sum of two number: 15
# Difference of two numbers: 5
# Product of two numbers: 50
# After division: 2.0
